# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10,12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.GR_entropy_foot2, logs.Depth, '-')
    ax[2].plot(logs.GR_entropy_foot3, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_entropy_foot4, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_entropy_foot5, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("GR_ent_foot2")
    ax[1].set_xlim(logs.GR_entropy_foot2.min(),logs.GR_entropy_foot2.max())
    ax[2].set_xlabel("GR_ent_foot3")
    ax[2].set_xlim(logs.GR_entropy_foot3.min(),logs.GR_entropy_foot3.max())
    ax[3].set_xlabel("GR_ent_foot4")
    ax[3].set_xlim(logs.GR_entropy_foot4.min(),logs.GR_entropy_foot4.max())
    ax[4].set_xlabel("GR_ent_foot5")
    ax[4].set_xlim(logs.GR_entropy_foot5.min(),logs.GR_entropy_foot5.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle(' GR entropy [2,3,4,5] foot for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
filename='E4facies.csv'
training_data=pd.read_csv(filename)

facies_colors = ['#F4D03F', '#F5B041','#DC7633','#6E2C00',
       '#1B4F72','#2E86C1', '#AED6F1', '#A569BD', '#196F3D']
       
facies_labels = ['SS', 'CSiS', 'FSiS', 'SiSh', 'MS', 'WS', 'D', 'PS', 'BS']

facies_color_map = {}
for ind, label in enumerate(facies_labels):
    facies_color_map[label] = facies_colors[ind]

# %% [markdown]
# GR and entropy [2,3,4,5] foot for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10,12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.GR_entropy_foot2, logs.Depth, '-')
    ax[2].plot(logs.GR_entropy_foot3, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_entropy_foot4, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_entropy_foot5, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("GR_ent_foot2")
    ax[1].set_xlim(logs.GR_entropy_foot2.min(),logs.GR_entropy_foot2.max())
    ax[2].set_xlabel("GR_ent_foot3")
    ax[2].set_xlim(logs.GR_entropy_foot3.min(),logs.GR_entropy_foot3.max())
    ax[3].set_xlabel("GR_ent_foot4")
    ax[3].set_xlim(logs.GR_entropy_foot4.min(),logs.GR_entropy_foot4.max())
    ax[4].set_xlabel("GR_ent_foot5")
    ax[4].set_xlim(logs.GR_entropy_foot5.min(),logs.GR_entropy_foot5.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle(' GR entropy [2,3,4,5] foot for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR and gradient [2,3,4,5] foot for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.GRgradient_dx2, logs.Depth, '-')
    ax[2].plot(logs.GRgradient_dx3, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GRgradient_dx4, logs.Depth, '-', color='r')
    ax[4].plot(logs.GRgradient_dx5, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("GRgrad_dx2")
    ax[1].set_xlim(logs.GRgradient_dx2.min(),logs.GRgradient_dx2.max())
    ax[2].set_xlabel("GRgrad_dx3")
    ax[2].set_xlim(logs.GRgradient_dx3.min(),logs.GRgradient_dx3.max())
    ax[3].set_xlabel("GRgrad_dx4")
    ax[3].set_xlim(logs.GRgradient_dx4.min(),logs.GRgradient_dx4.max())
    ax[4].set_xlabel("GRgrad_dx5")
    ax[4].set_xlim(logs.GRgradient_dx5.min(),logs.GRgradient_dx5.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR and gradients [2,3,4,5] for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR and moving average [1, 5, 10, 20] ft for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.GR_moving_av_1ft, logs.Depth, '-')
    ax[2].plot(logs.GR_moving_av_5ft, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_moving_av_10ft, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_moving_av_20ft, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("GR_mov_av1ft")
    ax[1].set_xlim(logs.GR_moving_av_1ft.min(),logs.GR_moving_av_1ft.max())
    ax[2].set_xlabel("GR_mov_av5ft")
    ax[2].set_xlim(logs.GR_moving_av_5ft.min(),logs.GR_moving_av_5ft.max())
    ax[3].set_xlabel("GR_mov_av10ft")
    ax[3].set_xlim(logs.GR_moving_av_10ft.min(),logs.GR_moving_av_10ft.max())
    ax[4].set_xlabel("GR_mov_av20ft")
    ax[4].set_xlim(logs.GR_moving_av_20ft.min(),logs.GR_moving_av_20ft.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR and moving averages [1,5,10,20] ft for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR and moving std [3, 5, 10, 20] ft for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.GR_moving_av_1ft, logs.Depth, '-')
    ax[2].plot(logs.GR_moving_av_5ft, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_moving_av_10ft, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_moving_av_20ft, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("GR_mov_sd3ft")
    ax[1].set_xlim(logs.GR_moving_std_3ft.min(),logs.GR_moving_std_3ft.max())
    ax[2].set_xlabel("GR_mov_sd5ft")
    ax[2].set_xlim(logs.GR_moving_std_5ft.min(),logs.GR_moving_std_5ft.max())
    ax[3].set_xlabel("GR_mov_sd10ft")
    ax[3].set_xlim(logs.GR_moving_std_10ft.min(),logs.GR_moving_std_10ft.max())
    ax[4].set_xlabel("GR_mov_sd20ft")
    ax[4].set_xlim(logs.GR_moving_std_20ft.min(),logs.GR_moving_std_20ft.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR and moving std [3,5,10,20] ft for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR and moving max [3, 5, 10, 15] ft for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.GR_moving_max_3ft, logs.Depth, '-')
    ax[2].plot(logs.GR_moving_max_5ft, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_moving_max_10ft, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_moving_max_15ft, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("GR_mov_max3ft")
    ax[1].set_xlim(logs.GR_moving_max_3ft.min(),logs.GR_moving_max_3ft.max())
    ax[2].set_xlabel("GR_mov_max5ft")
    ax[2].set_xlim(logs.GR_moving_max_5ft.min(),logs.GR_moving_max_5ft.max())
    ax[3].set_xlabel("GR_mov_max10ft")
    ax[3].set_xlim(logs.GR_moving_max_10ft.min(),logs.GR_moving_max_10ft.max())
    ax[4].set_xlabel("GR_mov_max15ft")
    ax[4].set_xlim(logs.GR_moving_max_15ft.min(),logs.GR_moving_max_15ft.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR and moving max [3,5,10,15] ft for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR and moving min std [3, 5, 10, 15] ft for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.GR_moving_min_3ft, logs.Depth, '-')
    ax[2].plot(logs.GR_moving_min_5ft, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_moving_min_10ft, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_moving_min_15ft, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("GR_moving_min_3ft")
    ax[1].set_xlim(logs.GR_moving_min_3ft.min(),logs.GR_moving_min_3ft.max())
    ax[2].set_xlabel("GR_moving_min_5ft")
    ax[2].set_xlim(logs.GR_moving_min_5ft.min(),logs.GR_moving_min_5ft.max())
    ax[3].set_xlabel("GR_moving_min_10ft")
    ax[3].set_xlim(logs.GR_moving_min_10ft.min(),logs.GR_moving_min_10ft.max())
    ax[4].set_xlabel("GR_moving_min_15ft")
    ax[4].set_xlim(logs.GR_moving_min_15ft.min(),logs.GR_moving_min_15ft.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR and moving min [3,5,10,15] ft for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR and marine ratio [5, 30, 75, 100] centered for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.Marine_ratio_5_centered, logs.Depth, '-')
    ax[2].plot(logs.Marine_ratio_30_centered, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.Marine_ratio_75_centered, logs.Depth, '-', color='r')
    ax[4].plot(logs.Marine_ratio_100_centered, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("MR_5_cent")
    ax[1].set_xlim(logs.Marine_ratio_5_centered.min(),logs.Marine_ratio_5_centered.max())
    ax[2].set_xlabel("MR_30_cent")
    ax[2].set_xlim(logs.Marine_ratio_30_centered.min(),logs.Marine_ratio_30_centered.max())
    ax[3].set_xlabel("MR_75_cent")
    ax[3].set_xlim(logs.Marine_ratio_75_centered.min(),logs.Marine_ratio_75_centered.max())
    ax[4].set_xlabel("MR_100_cent")
    ax[4].set_xlim(logs.Marine_ratio_100_centered.min(),logs.Marine_ratio_100_centered.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR and marine ratio [5,30,75,100] centered for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR and distance of marine up, down & non marine up, down for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.dist_M_up, logs.Depth, '-')
    ax[2].plot(logs.dist_M_down, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.dist_NM_up, logs.Depth, '-', color='r')
    ax[4].plot(logs.dist_NM_down, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("dist_M_up")
    ax[1].set_xlim(logs.dist_M_up.min(),logs.dist_M_up.max())
    ax[2].set_xlabel("dist_M_down")
    ax[2].set_xlim(logs.dist_M_down.min(),logs.dist_M_down.max())
    ax[3].set_xlabel("dist_NM_up")
    ax[3].set_xlim(logs.dist_NM_up.min(),logs.dist_NM_up.max())
    ax[4].set_xlabel("dist_NM_down")
    ax[4].set_xlim(logs.dist_NM_down.min(),logs.dist_NM_down.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR and dist of marine up, down & non marine up, down for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# GR, formation depth, softness indicator, GR/Depth, GR/resistivity for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.formation_depth, logs.Depth, '-')
    ax[2].plot(logs.soft_indic, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_Depth, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_ILD_log10, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("formation_depth")
    ax[1].set_xlim(logs.formation_depth.min(),logs.formation_depth.max())
    ax[2].set_xlabel("soft_indic")
    ax[2].set_xlim(logs.soft_indic.min(),logs.soft_indic.max())
    ax[3].set_xlabel("GR_Depth")
    ax[3].set_xlim(logs.GR_Depth.min(),logs.GR_Depth.max())
    ax[4].set_xlabel("GR_ILD_log10")
    ax[4].set_xlim(logs.GR_ILD_log10.min(),logs.GR_ILD_log10.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('GR, formation depth, softness indicator, GR/Depth, GR/Resictivity for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)

# %% [markdown]
# Ratios: GR/DeltaPHI, GR/PHIND, GR/PE, GR/NM_M, GR/RELPOS for Well ALEXANDER D

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(10, 12))
    ax[0].plot(logs.GR_DeltaPHI, logs.Depth, '-g')
    ax[1].plot(logs.GR_PHIND, logs.Depth, '-')
    ax[2].plot(logs.GR_PE, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.GR_NM_M, logs.Depth, '-', color='r')
    ax[4].plot(logs.GR_RELPOS, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR_DeltaPHI")
    ax[0].set_xlim(logs.GR_DeltaPHI.min(),logs.GR_DeltaPHI.max())
    ax[1].set_xlabel("GR_PHIND")
    ax[1].set_xlim(logs.GR_PHIND.min(),logs.GR_PHIND.max())
    ax[2].set_xlabel("GR_PE")
    ax[2].set_xlim(logs.GR_PE.min(),logs.GR_PE.max())
    ax[3].set_xlabel("GR_NM_M")
    ax[3].set_xlim(logs.GR_NM_M.min(),logs.GR_NM_M.max())
    ax[4].set_xlabel("GR_RELPOS")
    ax[4].set_xlim(logs.GR_RELPOS.min(),logs.GR_RELPOS.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('Ratios: GR/DeltaPHI, GR/PHIND, GR/PE, GR/NM_M, GR/RELPOS for Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)
    
    
make_facies_log_plot(
    training_data[training_data['Well Name'] == 'ALEXANDER D'],
    facies_colors)
